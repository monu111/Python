# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Pairplot

# %% [markdown]
# Pair Plot
# Lets say we have n number of features in a data, Pair plot will help us create us a (n x n) figure where the diagonal plots will be histogram plot of the feature corresponding to that row and rest of the plots are the combination of feature from each row in y axis and feature from each column in x axis.

# %% [markdown]
# - show the relation b/w the feature.

# %%
import seaborn as sns
import pandas as pd

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
sns.pairplot(dataset)

# %%
sns.pairplot(dataset, hue = 'Purchased')

# %%
sns.pairplot(dataset, hue = 'Purchased', kind = 'reg')

# %% [markdown]
# ### different dataset

# %%
df  = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue = 'day', kind = 'reg')
# Out:
# C:\Users\9875013747\anaconda3\envs\tf\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\9875013747\anaconda3\envs\tf\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, hue = 'sex', kind  ='reg')
