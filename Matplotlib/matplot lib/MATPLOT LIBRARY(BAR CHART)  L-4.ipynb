# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.plot(x,y, color = 'red', linewidth = 5, linestyle = '--')

# %%
plt.plot(x,y, color = 'red', linewidth = 5, linestyle = '--')

# %%
plt.plot(x,y, color = 'red', linewidth = 5, linestyle = '--')

# %%
plt.plot(x,y ,color = 'yellow', linewidth = 5, linestyle = '--')

# %%
plt.plot(x,y,'g+')

# %%
plt.plot(x,y, 'r*--')

# %%
plt.plot(x,y, '--r*')

# %%
plt.plot(x,y, '--rD')

# %%
plt.plot(x,y, '--gD')

# %%
plt.plot(x,y, marker = '+',color = 'red', markersize = 20, linewidth = 3, linestyle = '-')

# %%
plt.plot(x,y,marker = '*', color = 'red', markersize =  20, linewidth = 3, linestyle = '--', label = 'Temp')
plt.title('Weather')
plt.xlabel('days')
plt.ylabel('temperature')
#plt.legend()
plt.show()
